# %%
import pandas as pd

# %%
fname = "data/ev_sales/ev_data_preprocessed.csv"

df = pd.read_csv(fname)
df['ev_market_share'] = df['ev_market_share']*100
m = df[df['year'] == 2019][['State Name', 'ev_market_share']].sort_values(by='ev_market_share', ascending=False)
m.to_csv("output_files/Table_S8.csv", index=False)

# %%
df
# Out:
#              State  FCEV Sales  FCEV Market Share  BEV Sales  \
# 0          Alabama           0                NaN         18
# 1           Alaska           0                NaN          2
# 2          Arizona           0                NaN        355
# 3         Arkansas           0                NaN          2
# 4       California          19                NaN       5062
# ..             ...         ...                ...        ...
# 454       Virginia           0                0.0       5677
# 455     Washington           0                0.0      10256
# 456  West Virginia           0                0.0        179
# 457      Wisconsin           0                0.0       1381
# 458        Wyoming           0                0.0        100
#
#      BEV Market Share  PHEV Sales  PHEV Market Share  year     State Name  \
# 0                 NaN          55                NaN  2011        Alabama
# 1                 NaN           4                NaN  2011         Alaska
# ...

# %%
df[df['year'] == 2019][df['State Name'] == 'California']
# Out:
# C:\Users\harsh\AppData\Local\Temp\ipykernel_37972\3272082657.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df[df['year'] == 2019][df['State Name'] == 'California']
#           State  FCEV Sales  FCEV Market Share  BEV Sales  BEV Market Share  \
# 412  California        1764             0.0009     100549            0.0516
#
#      PHEV Sales  PHEV Market Share  year  State Name  state_code  EPA Region  \
# 412       44471             0.0228  2019  California           6         9.0
#
#      ev_sales  ev_market_share      total  nonev_sales
# 412    146784             7.53  1950483.0    1803699.0

# %%
0.0516+0.0228
# Out:
# 0.0744
