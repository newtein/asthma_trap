# %%
import pandas as pd

# %%
f = 'output_files/model_AC_2013_2019_no2.csv'

# %%
df = pd.read_csv(f)

# %%
# df.boxplot(column=['AC'])
df[df['AC']<=6000]['AC'].plot.hist(bins=20, alpha=0.7)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df['nonev_sales'].plot.hist(bins=20, alpha=0.7)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df.boxplot(column=['nonev_sales'])
# Out:
# <AxesSubplot:>
